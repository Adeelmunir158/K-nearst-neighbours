# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("FAOSTAT_data_3-19-2022.csv")
data
# Out:
#     Domain Code                   Domain  Area Code      Area  Element Code  \
# 0           RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 1           RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 2           RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 3           RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 4           RFN  Fertilizers by Nutrient        165  Pakistan          5157
# ..          ...                      ...        ...       ...           ...
# 167         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 168         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 169         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 170         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 171         RFN  Fertilizers by Nutrient        165  Pakistan          5157
#
# ...

# %%
data.describe()
# Out:
#        Area Code  Element Code    Item Code    Year Code         Year  \
# count      172.0         172.0   172.000000   172.000000   172.000000
# mean       165.0        5157.0  3102.970930  1990.784884  1990.784884
# std          0.0           0.0     0.812385    16.678775    16.678775
# min        165.0        5157.0  3102.000000  1961.000000  1961.000000
# 25%        165.0        5157.0  3102.000000  1976.750000  1976.750000
# 50%        165.0        5157.0  3103.000000  1991.000000  1991.000000
# 75%        165.0        5157.0  3104.000000  2005.000000  2005.000000
# max        165.0        5157.0  3104.000000  2019.000000  2019.000000
#
#               Value
# count  1.720000e+02
# mean   7.064396e+05
# std    9.709749e+05
# min    1.440000e+02
# 25%    2.615950e+04
# 50%    2.689255e+05
# 75%    9.193622e+05
# max    3.505356e+06

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
hi=pd.read_csv("FAOSTAT_data_3-19-2022.csv")

hi.head(5)
# Out:
#   Domain Code                   Domain  Area Code      Area  Element Code  \
# 0         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 1         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 2         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 3         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 4         RFN  Fertilizers by Nutrient        165  Pakistan          5157
#
#             Element  Item Code                             Item  Year Code  \
# 0  Agricultural Use       3102      Nutrient nitrogen N (total)       1961
# 1  Agricultural Use       3103  Nutrient phosphate P2O5 (total)       1961
# 2  Agricultural Use       3103  Nutrient phosphate P2O5 (total)       1962
# 3  Agricultural Use       3102      Nutrient nitrogen N (total)       1962
# 4  Agricultural Use       3102      Nutrient nitrogen N (total)       1963
#
# ...

# %%
hi.mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_7640/579395277.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   hi.mean()
# Area Code          165.000000
# Element Code      5157.000000
# Item Code         3102.970930
# Year Code         1990.784884
# Year              1990.784884
# Value           706439.558140
# dtype: float64

# %%
hi.groupby(["Area Code","Item Code"]).mean ()
# Out:
#                      Element Code  Year Code    Year         Value
# Area Code Item Code
# 165       3102             5157.0     1990.0  1990.0  1.598544e+06
#           3103             5157.0     1990.0  1990.0  4.414284e+05
#           3104             5157.0     1992.5  1992.5  2.128265e+04

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
hi=pd.read_csv("FAOSTAT_data_3-19-2022.csv")
sns.barplot(x="Year", y="Value", data=hi, saturation=.5)
plt.show(block=True)

# %%
import seaborn as sns
sns.set_theme(style="white")
# Load the example mpg dataset
ha = sns.load_dataset("mpg")
# Plot miles per gallon against horsepower with other semantics
sns.relplot(x="horsepower", y="mpg", hue="origin", size="weight",
sizes=(40, 400), alpha=.5, palette="muted",
height=6, data=mpg)

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
hi=pd.read_csv("FAOSTAT_data_3-19-2022.csv")
sns.catplot(x="Year", y="Value", kind="bar",data=hi)
plt.show()

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
hi=pd.read_excel("district.xls")
sns.boxplot(x="Year", y="Value",data=hi)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7640/1282661738.py in <module>
#       4 import matplotlib.pyplot as plt
#       5 hi=pd.read_csv("FAOSTAT_data_3-19-2022.csv")
# ----> 6 g=(g.map(plt.scatter,"Year","Value").add_legend())
#       7 plt.show()
#       8
#
# NameError: name 'g' is not defined

# %%
ha=pd.read_csv("harvested.csv")
ha
# Out:
#      Element Code         Element  Year Code  Year     Value Flag
# 0            5312  Area harvested       1961  1961   7858558    A
# 1            5419           Yield       1961  1961      8564   Fc
# 2            5510      Production       1961  1961   6729680    A
# 3            5312  Area harvested       1962  1962   8090856    A
# 4            5419           Yield       1962  1962      8580   Fc
# ..            ...             ...        ...   ...       ...  ...
# 175          5419           Yield       2019  2019     28938   Fc
# 176          5510      Production       2019  2019  40205238    A
# 177          5312  Area harvested       2020  2020  14082566    A
# 178          5419           Yield       2020  2020     30208   Fc
# 179          5510      Production       2020  2020  42540915    A
#
# [180 rows x 6 columns]

# %%
ha.mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_7640/3946583141.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ha.mean()
# Element Code    5.413667e+03
# Year Code       1.990500e+03
# Year            1.990500e+03
# Value           1.161077e+07
# dtype: float64

# %%
ha.describe()
# Out:
#        Element Code    Year Code         Year         Value
# count    180.000000   180.000000   180.000000  1.800000e+02
# mean    5413.666667  1990.500000  1990.500000  1.161077e+07
# std       81.146808    17.366409    17.366409  1.157594e+07
# min     5312.000000  1961.000000  1961.000000  8.400000e+03
# 25%     5312.000000  1975.750000  1975.750000  2.596750e+04
# 50%     5419.000000  1990.500000  1990.500000  1.104450e+07
# 75%     5510.000000  2005.250000  2005.250000  1.413153e+07
# max     5510.000000  2020.000000  2020.000000  4.430000e+07

# %%
ha.head(4)
# Out:
#    Element Code         Element  Year Code  Year    Value Flag
# 0          5312  Area harvested       1961  1961  7858558    A
# 1          5419           Yield       1961  1961     8564   Fc
# 2          5510      Production       1961  1961  6729680    A
# 3          5312  Area harvested       1962  1962  8090856    A

# %%
hb=ha.loc[1:10,:]

# %%
hb
# Out:
#     Element Code         Element  Year Code  Year    Value Flag
# 1           5419           Yield       1961  1961     8564   Fc
# 2           5510      Production       1961  1961  6729680    A
# 3           5312  Area harvested       1962  1962  8090856    A
# 4           5419           Yield       1962  1962     8580   Fc
# 5           5510      Production       1962  1962  6941600    A
# 6           5312  Area harvested       1963  1963  8212602    A
# 7           5419           Yield       1963  1963     8777   Fc
# 8           5510      Production       1963  1963  7208300    A
# 9           5312  Area harvested       1964  1964  8533549    A
# 10          5419           Yield       1964  1964     8865   Fc

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
hb=ha.loc[1:10,:]
sns.barplot(x="Year", y="Value", data=hb, saturation=.5)
plt.show()

# %%
hb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7772/829694283.py in <module>
# ----> 1 hb
#
# NameError: name 'hb' is not defined

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
hb=ha.loc[1:10,:]
hb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7772/1631016161.py in <module>
#       3 import pandas as pd
#       4 import matplotlib.pyplot as plt
# ----> 5 hb=ha.loc[1:10,:]
#       6 hb
#       7
#
# NameError: name 'ha' is not defined

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)
demo = pd.read_excel (r'C:\Users\Admin\Documents\Drive D\Video\R Studio\demo.xlsx', sheet_name="demo")
sns.catplot(x="income", y="math", kind="bar", data=demo)
plt.show()

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
hb=ha.loc[1:10,:]

sns.set_theme(style="white")

hb=ha.loc[1:10,:]

sns.barplot(x="Year", y="Value", data="hb")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7772/2002875031.py in <module>
#       3 import pandas as pd
#       4 import matplotlib.pyplot as plt
# ----> 5 hb=ha.loc[1:10,:]
#       6
#       7 sns.set_theme(style="white")
#
# NameError: name 'ha' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)
phool=sns.load_dataset("iris")
phool
sns.barplot(x="species", y="sepal_width", data=phool)
plt.show()

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
di=pd.read_excel (r'C:\Users\Admin\Downloads\Documents\Pakistan beuru of statistics\district.xlsx', sheet_name="1981-2021")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7772/294108759.py in <module>
# ----> 1 di=pd.read_excel (r'C:\Users\Admin\Downloads\Documents\Pakistan beuru of statistics\district.xlsx', sheet_name="1981-2021")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
# ...

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
di=pd.read_excel("district.xls")
di
# Out:
#     STATEMENT SHOWING THE NUMBER OF PAKISTANIS REGISTERED FOR EMPLOYMENT ABROAD DURING THE PERIOD 1981-2022 (upto February)  \
# 0                                                  S.#
# 1                                                  NaN
# 2                                                    1
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 152                                                151
# 153                                                152
# 154                                                153
# 155                                                154
# 156                                                NaN
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0      Districts  1981-2007      2008.0      2009.0      2010.0      2011.0
# 1            NaN        NaN         NaN         NaN         NaN         NaN
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)
demo = pd.read_excel (r'C:\Users\Admin\Documents\Drive D\Video\R Studio\demo.xlsx', sheet_name="demo")
sns.catplot(x="income", y="math", kind="bar", data=demo)
plt.show()

# %%
pip install ipymp
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement ipymp (from versions: none)
# ERROR: No matching distribution found for ipymp
